# %%
database_path = "/Users/achowd6/Codes/itac-report-validator/docs/report1/IACAssessmentTemplate.v2.1.xlsx"

import pandas as pd

# Read all sheets from the Excel file into a dictionary of DataFrames
all_sheets = pd.read_excel(database_path, sheet_name=None)

# %%
recommendation_info = all_sheets['Recommendation Info']

recommendation_info.head()
# Out:
#    RECOMMENDATIONS Unnamed: 1 Unnamed: 2  \
# 0              NaN        NaN        NaN
# 1              NaN   ARC Code   APP Code
# 2              1.0     2.7211        NaN
# 3              2.0     2.4231        NaN
# 4              3.0     2.7135        NaN
#
#                                           Unnamed: 3         Unnamed: 4  \
# 0                                                NaN            Primary
# 1                             Additional Description     Resource Steam
# 2         HVAC Tune-Up To Increase Energy Efficiency  Electricity Usage
# 3  Reduce the Discharge Pressure of the compresse...  Electricity Usage
# 4                          Install Occupancy Sensors  Electricity Usage
#
#      Unnamed: 5  Unnamed: 6 Unnamed: 7      Unnamed: 8    Unnamed: 9  ...  \
# 0           NaN         NaN        NaN       Secondary           NaN  ...
# 1  Unit Savings        Unit  $ Savings  Resource Steam  Unit Savings  ...
# 2         72020  kWh (site)       8066             NaN           NaN  ...
# 3         24928  kWh (site)       2792             NaN           NaN  ...
# 4         56313  kWh (site)       6307             NaN           NaN  ...
#
#   Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28         Unnamed: 29  \
# 0         NaN         NaN         NaN         NaN                 NaN
# 1     Rebates         NaN         NaN         NaN   Electricity Usage
# 2           Y         NaN         NaN         NaN  Electricity Demand
# 3           N         NaN         NaN         NaN    Electricity Fees
# 4           Y         NaN         NaN         NaN         Natural Gas
#
#              Unnamed: 30     Unnamed: 31 Unnamed: 32 Unnamed: 33  \
# 0  Recource Stream Codes             NaN         NaN     BP Tool
# 1                     EC      kWh (site)         NaN        none
# 2                     ED  kW Months / yr         NaN         AM+
# 3                     EF        no units         NaN       CWSAT
# 4                     E2           MMBtu         NaN        FSAT
#
#                           Unnamed: 34
# 0                                 NaN
# 1                                 NaN
# 2                          AirMaster+
# 3  Chilled Water System Analysis Tool
# 4   Fan System Assessment Tool (FSAT)
#
# [5 rows x 35 columns]

# %%
recommendation_info[2:3]
# Out:
#    RECOMMENDATIONS Unnamed: 1 Unnamed: 2  \
# 2              1.0     2.7211        NaN
#
#                                    Unnamed: 3         Unnamed: 4 Unnamed: 5  \
# 2  HVAC Tune-Up To Increase Energy Efficiency  Electricity Usage      72020
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 25 Unnamed: 26  \
# 2  kWh (site)       8066        NaN        NaN  ...           Y         NaN
#
#   Unnamed: 27 Unnamed: 28         Unnamed: 29 Unnamed: 30     Unnamed: 31  \
# 2         NaN         NaN  Electricity Demand          ED  kW Months / yr
#
#   Unnamed: 32 Unnamed: 33 Unnamed: 34
# 2         NaN         AM+  AirMaster+
#
# [1 rows x 35 columns]
