# %%
database_path = "/Users/achowd6/Codes/itac-report-validator/docs/report1/IACAssessmentTemplate.v2.1.xlsx"

import pandas as pd

# Read all sheets from the Excel file into a dictionary of DataFrames
all_sheets = pd.read_excel(database_path, sheet_name=None)

# %%
all_sheets.keys()
# Out:
# dict_keys(['General Info', 'Energy-Waste Info', 'Recommendation Info', 'Data'])

# %%
# read the data from 'Energy-Waste Info' sheet
energy_waste_info = all_sheets['Energy-Waste Info']

energy_waste_info.head()
# Out:
#                 Unnamed: 0 DO NOT FORMAT THESE COLUMNS Unnamed: 2  \
# 0        Energy/Waste Info                 Consumption       Cost
# 1  Electrical Consumption                      2763509     308828
# 2       Electrical Demand                         2483       8408
# 3   Other Electrical Fees                          NaN        NaN
# 4             Natural Gas                         2325      12911
#
#     Unnamed: 3    Unnamed: 4 Unnamed: 5 Unnamed: 6        Unnamed: 7  \
# 0  Consumption           NaN       Cost  Unit Cost               NaN
# 1      2763509           kWh     308828   0.111752           per kWh
# 2         2483  kW months/yr       8408   3.386226  per kW months/yr
# 3          NaN           NaN          0        NaN              per
# 4         2325         MMBtu      12911   5.553118         per MMBtu
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0         NaN         NaN          NaN          NaN
# ...
